# %%
import numpy as np
import pandas as pd
import requests
import json

url = "https://data.covid19india.org/v4/min/timeseries.min.json"
JSONContent = requests.get(url).json()

# %%
states = []
dates = []
dic = {}

json = JSONContent

for state in json:
    states.append(state)
    x = json[state]
    for i in x['dates']:
        dates.append(i)
#print(dates)
#print(states)
for currdate in dates:
    dic[currdate] = {}
    
for currstate in  states:
    for currdate in dates:
        if currdate in json[currstate]['dates']:
            
            val = json[currstate]['dates'][currdate]
            if 'delta' in val:
                x = val['delta']
                if 'confirmed' in x:
                    dic[currdate][currstate]  = x['confirmed']
                    #print(x['confirmed'])
                else:
                    dic[currdate][currstate]  = 0
                    #print(0)
            else:
                dic[currdate][currstate]  = 0
                #print(0)
        else:
            dic[currdate][currstate]  = 0
             #print(0)
print(dic)
# Out:
# {'2020-03-26': {'AN': 1, 'AP': 1, 'AR': 0, 'AS': 0, 'BR': 3, 'CH': 0, 'CT': 3, 'DL': 4, 'DN': 0, 'GA': 0, 'GJ': 6, 'HP': 0, 'HR': 1, 'JH': 0, 'JK': 3, 'KA': 4, 'KL': 19, 'LA': 0, 'LD': 0, 'MH': 3, 'ML': 0, 'MN': 0, 'MP': 5, 'MZ': 0, 'NL': 0, 'OR': 1, 'PB': 2, 'PY': 0, 'RJ': 5, 'SK': 0, 'TG': 4, 'TN': 3, 'TR': 0, 'TT': 73, 'UN': 0, 'UP': 4, 'UT': 0, 'WB': 1}, '2020-03-27': {'AN': 5, 'AP': 2, 'AR': 0, 'AS': 0, 'BR': 2, 'CH': 1, 'CT': 0, 'DL': 1, 'DN': 0, 'GA': 0, 'GJ': 3, 'HP': 0, 'HR': 1, 'JH': 0, 'JK': 6, 'KA': 9, 'KL': 39, 'LA': 0, 'LD': 0, 'MH': 28, 'ML': 0, 'MN': 0, 'MP': 9, 'MZ': 0, 'NL': 0, 'OR': 0, 'PB': 5, 'PY': 0, 'RJ': 7, 'SK': 0, 'TG': 14, 'TN': 9, 'TR': 0, 'TT': 153, 'UN': 0, 'UP': 7, 'UT': 0, 'WB': 5}, '2020-03-28': {'AN': 3, 'AP': 6, 'AR': 0, 'AS': 0, 'BR': 2, 'CH': 0, 'CT': 1, 'DL': 9, 'DN': 0, 'GA': 0, 'GJ': 8, 'HP': 0, 'HR': 2, 'JH': 0, 'JK': 13, 'KA': 12, 'KL': 6, 'LA': 0, 'LD': 0, 'MH': 28, 'ML': 0, 'MN': 0, 'MP': 10, 'MZ': 0, 'NL': 0, 'OR': 0, 'PB': 0, 'PY': 0, 'RJ': 4, 'SK': 0, 'TG': 8, 'TN': 4, 'TR': 0, 'TT': 136, 'UN': 0, 'UP': 16, 'UT': 1, 'WB': 3}, '2020-03-29': {'AN': 0, 'AP': 2, 'AR': 0, 'AS': 0, 'BR': 4, 'CH': 0, 'CT': 0, 'DL': 23, 'DN': 0, 'GA': 2, 'GJ': 8, 'HP': 0, 'H
 3, 'WB': 16}, '2020-04-03': {'AN': 0, 'AP': 15, 'AR': 0, 'AS': 7, 'BR': 2, 'CH': 0, 'CT': 0, 'DL': 93, 'DN': 0, 'GA': 1, 'GJ': 7, 'HP': 0, 'HR': 9, 'JH': 0, 'JK': 5, 'KA': 4, 'KL': 9, 'LA': 1, 'LD': 0, 'MH': 64, 'ML': 0, 'MN': 0, 'MP': 47, 'MZ': 0, 'NL': 0, 'OR': 15, 'PB': 6, 'PY': 0, 'RJ': 46, 'SK': 0, 'TG': 75, 'TN': 102, 'TR': 0, 'TT': 560, 'UN': 0, 'UP': 46, 'UT': 6, 'WB': 0}, '2020-04-04': {'AN': 0, 'AP': 28, 'AR': 0, 'AS': 3, 'BR': 1, 'CH': 0, 'CT': 1, 'DL': 59, 'DN': 0, 'GA': 1, 'GJ': 13, 'HP': 7, 'HR': 26, 'JH': 0, 'JK': 17, 'KA': 16, 'KL': 11, 'LA': 0, 'LD': 0, 'MH': 148, 'ML': 0, 'MN': 0, 'MP': 25, 'MZ': 0, 'NL': 0, 'OR': 1, 'PB': 12, 'PY': 0, 'RJ': 27, 'SK': 0, 'TG': 43, 'TN': 74, 'TR': 0, 'TT': 579, 'UN': 0, 'UP': 60, 'UT': 6, 'WB': 0}, '2020-04-05': {'AN': 0, 'AP': 64, 'AR': 0, 'AS': 0, 'BR': 0, 'CH': 0, 'CT': 0, 'DL': 58, 'DN': 0, 'GA': 0, 'GJ': 20, 'HP': 1, 'HR': 6, 'JH': 1, 'JK': 14, 'KA': 7, 'KL': 8, 'LA': 0, 'LD': 0, 'MH': 112, 'ML': 0, 'MN': 0, 'MP': 14, 'MZ': 0, 'NL': 0, 'OR': 18, 'PB': 3, 'PY': 0, 'RJ': 60, 'SK': 0, 'TG': 62, 'TN': 86, 'TR': 0, ' ...

# %%
nd = {}
f = 0
for state in states:
    nd[state] = []
    for currdate in dates:
        nd[state].append(dic[currdate][state])
        f+=1
#print(f)        
#print(nd['WB'])

# %%
import csv

# %%
ndframe = pd.DataFrame.from_dict(nd)
ndframe['date'] = dates

# %%
ndframe.head()
# Out:
#    AN  AP  AR  AS  BR  CH  CT  DL  DN  GA  ...  SK  TG  TN  TR   TT  UN  UP  \
# 0   1   1   0   0   3   0   3   4   0   0  ...   0   4   3   0   73   0   4
# 1   5   2   0   0   2   1   0   1   0   0  ...   0  14   9   0  153   0   7
# 2   3   6   0   0   2   0   1   9   0   0  ...   0   8   4   0  136   0  16
# 3   0   2   0   0   4   0   0  23   0   2  ...   0   3   8   0  120   0   7
# 4   1   2   0   0   0   5   1  25   0   0  ...   0   7  17   0  187   0  24
#
#    UT  WB        date
# 0   0   1  2020-03-26
# 1   0   5  2020-03-27
# 2   1   3  2020-03-28
# 3   1   3  2020-03-29
# 4   0   1  2020-03-30
#
# [5 rows x 39 columns]

# %%
ndframe.to_csv('finalcsv.csv')
